# %% [markdown]
# # Resample Fruad=1 Class
# - Train using Keras DNN

# %%
import pandas as pd
import numpy as np
import keras

from collections import Counter

from sklearn.utils import resample, shuffle

from keras.layers import Dense, Dropout, BatchNormalization

from sklearn.metrics import roc_auc_score

from multiprocessing import cpu_count

from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE

import xgboost as xgb

from sklearn.model_selection import StratifiedKFold
from tqdm import tqdm

# !python -c 'import tensorflow as tf; print(tf.version)'
print(cpu_count())
# Out:
# Using TensorFlow backend.
# <module 'tensorflow._api.v1.version' from '/home/ec2-user/anaconda3/lib/python3.7/site-packages/tensorflow/_api/v1/version/__init__.py'>
# 4

# %% [markdown]
# # Read Dataset

# %%
def get_string_features(df):
    string_features = []
    for col in df.columns:
        if df[col].dtype == np.dtype('object'):
            string_features.append(col)

    return string_features


def read_data(filename='./datasets/kfold/transaction_fold_0_0_0.csv',
              filename_identity=None,
              drop_string_features=True):
    
    df = pd.read_csv(filename)
    
    if filename_identity is not None:
        df_identity = pd.read_csv(filename_identity)
        
        df = pd.merge(df, df_identity, on='TransactionID', how='left')
        
        del df_identity
    
    
    if drop_string_features:
        string_features = get_string_features(df)
        df = df.drop(columns=string_features)
    
    return df

# %%
filename = './datasets/train_transaction.csv'
filename_identity = './datasets/train_identity.csv'

# %time train = read_data(filename, drop_string_features=False)

# %time train = read_data(filename, filename_identity, drop_string_features=False)

# %time train = read_data(drop_string_features=False)
# Out:
# CPU times: user 25.4 s, sys: 7.74 s, total: 33.1 s
# Wall time: 32.2 s

# %%
train.shape
# Out:
# (590540, 434)

# %%
train.isFraud.value_counts()
# Out:
# 0    569877
# 1     20663
# Name: isFraud, dtype: int64

# %% [markdown]
# # Encode Labels

# %%
def encode(df, mappings=None):
    if mappings is None:
        create_mappings = True
        mappings= {}
    else:
        create_mappings = False
        

    string_features = get_string_features(df)
    
    for feature in string_features:
        if create_mappings:
            uniques = df[feature].unique()
            m = dict(zip(uniques, range(len(uniques))))
            mappings[feature] = m
        else:
            m = mappings[feature]
        
        df[feature] = df[feature].map(m)
        
    return mappings

# %%
# %time mappings = encode(train)
# Out:
# CPU times: user 8.79 s, sys: 212 ms, total: 9 s
# Wall time: 4.51 s

# %%
mappings
# Out:
# {'ProductCD': {'W': 0, 'H': 1, 'C': 2, 'S': 3, 'R': 4},
#  'card4': {'discover': 0,
#   'mastercard': 1,
#   'visa': 2,
#   'american express': 3,
#   nan: 4},
#  'card6': {'credit': 0,
#   'debit': 1,
#   nan: 2,
#   'debit or credit': 3,
#   'charge card': 4},
#  'P_emaildomain': {nan: 0,
#   'gmail.com': 1,
#   'outlook.com': 2,
#   'yahoo.com': 3,
#   'mail.com': 4,
#   'anonymous.com': 5,
#   'hotmail.com': 6,
#   'verizon.net': 7,
#   'aol.com': 8,
#   'me.com': 9,
#   'comcast.net': 10,
#   'optonline.net': 11,
#   'cox.net': 12,
#   'charter.net': 13,
#   'rocketmail.com': 14,
#   'prodigy.net.mx': 15,
#   'embarqmail.com': 16,
#   'icloud.com': 17,
#   'live.com.mx': 18,
#   'gmail': 19,
#   'live.com': 20,
#   'att.net': 21,
#   'juno.com': 22,
#   'ymail.com': 23,
#   'sbcglobal.net': 24,
#   'bellsouth.net': 25,
#   'msn.com': 26,
#   'q.com': 27,
#   'yahoo.com.mx': 28,
#   'centurylink.net': 29,
#   'servicios-ta.com': 30,
#   'earthlink.net': 31,
#   'hotmail.es': 32,
#   'cfl.rr.com': 33,
#   'roadrunner.com': 34,
#   'netzero.net': 35,
#   'gmx.de': 36,
#   'suddenlink.net': 37,
#   'frontiernet.net': 38,
#   'windstream.net': 39,
#   'frontier.com': 40,
#   'outlook.es': 41,
#   'mac.com': 42,
#   'netzero.com': 43,
#   'aim.com': 44,
#   'web.de': 45,
#   'twc.com': 46,
#   'cableone.net': 47,
#   'yahoo.fr': 48,
#   'yahoo.de': 49,
#   'yahoo.es': 50,
#   'sc.rr.com': 51,
#   'ptd.net': 52,
#   'live.fr': 53,
#   'yahoo.co.uk': 54,
#   'hotmail.fr': 55,
#   'hotmail.de': 56,
#   'hotmail.co.uk': 57,
#   'protonmail.com': 58,
#   'yahoo.co.jp': 59},
#  'R_emaildomain': {nan: 0,
#   'gmail.com': 1,
#   'hotmail.com': 2,
#   'outlook.com': 3,
#   'anonymous.com': 4,
#   'charter.net': 5,
#   'prodigy.net.mx': 6,
#   'comcast.net': 7,
#   'live.com.mx': 8,
#   'icloud.com': 9,
#   'yahoo.com': 10,
#   'aol.com': 11,
#   'juno.com': 12,
#   'att.net': 13,
#   'verizon.net': 14,
#   'yahoo.com.mx': 15,
#   'bellsouth.net': 16,
#   'servicios-ta.com': 17,
#   'ymail.com': 18,
#   'hotmail.es': 19,
#   'msn.com': 20,
#   'optonline.net': 21,
#   'live.com': 22,
#   'gmx.de': 23,
#   'aim.com': 24,
#   'mail.com': 25,
#   'me.com': 26,
#   'outlook.es': 27,
#   'cox.net': 28,
#   'earthlink.net': 29,
#   'embarqmail.com': 30,
#   'web.de': 31,
#   'sbcglobal.net': 32,
#   'scranton.edu': 33,
#   'mac.com': 34,
#   'twc.com': 35,
#   'roadrunner.com': 36,
#   'yahoo.fr': 37,
#   'yahoo.de': 38,
#   'yahoo.es': 39,
#   'frontiernet.net': 40,
#   'gmail': 41,
#   'live.fr': 42,
#   'q.com': 43,
#   'yahoo.co.uk': 44,
#   'windstream.net': 45,
#   'suddenlink.net': 46,
#   'hotmail.fr': 47,
#   'ptd.net': 48,
#   'hotmail.de': 49,
#   'frontier.com': 50,
#   'cfl.rr.com': 51,
#   'hotmail.co.uk': 52,
#   'netzero.com': 53,
#   'netzero.net': 54,
#   'yahoo.co.jp': 55,
#   'rocketmail.com': 56,
#   'centurylink.net': 57,
#   'protonmail.com': 58,
#   'cableone.net': 59,
#   'sc.rr.com': 60},
#  'M1': {'T': 0, nan: 1, 'F': 2},
#  'M2': {'T': 0, nan: 1, 'F': 2},
#  'M3': {'T': 0, nan: 1, 'F': 2},
#  'M4': {'M2': 0, 'M0': 1, nan: 2, 'M1': 3},
#  'M5': {'F': 0, 'T': 1, nan: 2},
#  'M6': {'T': 0, 'F': 1, nan: 2},
#  'M7': {nan: 0, 'F': 1, 'T': 2},
#  'M8': {nan: 0, 'F': 1, 'T': 2},
#  'M9': {nan: 0, 'F': 1, 'T': 2},
#  'id_12': {nan: 0, 'NotFound': 1, 'Found': 2},
#  'id_15': {nan: 0, 'New': 1, 'Found': 2, 'Unknown': 3},
#  'id_16': {nan: 0, 'NotFound': 1, 'Found': 2},
#  'id_23': {nan: 0,
#   'IP_PROXY:TRANSPARENT': 1,
#   'IP_PROXY:ANONYMOUS': 2,
#   'IP_PROXY:HIDDEN': 3},
#  'id_27': {nan: 0, 'Found': 1, 'NotFound': 2},
#  'id_28': {nan: 0, 'New': 1, 'Found': 2},
#  'id_29': {nan: 0, 'NotFound': 1, 'Found': 2},
#  'id_30': {nan: 0,
#   'Android 7.0': 1,
#   'iOS 11.1.2': 2,
#   'Mac OS X 10_11_6': 3,
#   'Windows 10': 4,
#   'Android': 5,
#   'Linux': 6,
#   'iOS 11.0.3': 7,
#   'Mac OS X 10_7_5': 8,
#   'Mac OS X 10_12_6': 9,
#   'Mac OS X 10_13_1': 10,
#   'iOS 11.1.0': 11,
#   'Mac OS X 10_9_5': 12,
#   'Windows 7': 13,
#   'Windows 8.1': 14,
#   'Mac': 15,
#   'iOS 10.3.3': 16,
#   'Mac OS X 10.12': 17,
#   'Mac OS X 10_10_5': 18,
#   'Mac OS X 10_11_5': 19,
#   'iOS 9.3.5': 20,
#   'Android 5.1.1': 21,
#   'Android 7.1.1': 22,
#   'Android 6.0': 23,
#   'iOS 10.3.1': 24,
#   'Mac OS X 10.9': 25,
#   'iOS 11.1.1': 26,
#   'Windows Vista': 27,
#   'iOS 10.3.2': 28,
#   'iOS 11.0.2': 29,
#   'Mac OS X 10.11': 30,
#   'Android 8.0.0': 31,
#   'iOS 10.2.0': 32,
#   'iOS 10.2.1': 33,
#   'iOS 11.0.0': 34,
#   'Mac OS X 10.10': 35,
#   'Mac OS X 10_12_3': 36,
#   'Mac OS X 10_12': 37,
#   'Android 6.0.1': 38,
#   'iOS': 39,
#   'Mac OS X 10.13': 40,
#   'Mac OS X 10_12_5': 41,
#   'Mac OS X 10_8_5': 42,
#   'iOS 11.0.1': 43,
#   'iOS 10.0.2': 44,
#   'Android 5.0.2': 45,
#   'Windows XP': 46,
#   'iOS 11.2.0': 47,
#   'Mac OS X 10.6': 48,
#   'Windows 8': 49,
#   'Mac OS X 10_6_8': 50,
#   'Mac OS X 10_11_4': 51,
#   'Mac OS X 10_12_1': 52,
#   'iOS 10.1.1': 53,
#   'Mac OS X 10_11_3': 54,
#   'Mac OS X 10_12_4': 55,
#   'Mac OS X 10_13_2': 56,
#   'Android 4.4.2': 57,
#   'Mac OS X 10_12_2': 58,
#   'Android 5.0': 59,
#   'func': 60,
#   'Android 7.1.2': 61,
#   'Android 8.1.0': 62,
#   'other': 63,
#   'Mac OS X 10_13_3': 64,
#   'iOS 11.2.1': 65,
#   'iOS 11.2.5': 66,
#   'Windows': 67,
#   'iOS 11.2.2': 68,
#   'iOS 11.3.0': 69,
#   'iOS 11.2.6': 70,
#   'Mac OS X 10_13_4': 71,
#   'Mac OS X 10_13_5': 72,
#   'iOS 11.4.0': 73,
#   'iOS 11.3.1': 74,
#   'iOS 11.4.1': 75},
#  'id_31': {nan: 0,
#   'samsung browser 6.2': 1,
#   'mobile safari 11.0': 2,
#   'chrome 62.0': 3,
#   'chrome 62.0 for android': 4,
#   'edge 15.0': 5,
#   'mobile safari generic': 6,
#   'chrome 49.0': 7,
#   'chrome 61.0': 8,
#   'edge 16.0': 9,
#   'safari generic': 10,
#   'edge 14.0': 11,
#   'chrome 56.0 for android': 12,
#   'firefox 57.0': 13,
#   'chrome 54.0 for android': 14,
#   'mobile safari uiwebview': 15,
#   'chrome': 16,
#   'chrome 62.0 for ios': 17,
#   'firefox': 18,
#   'chrome 60.0 for android': 19,
#   'mobile safari 10.0': 20,
#   'chrome 61.0 for android': 21,
#   'ie 11.0 for desktop': 22,
#   'ie 11.0 for tablet': 23,
#   'mobile safari 9.0': 24,
#   'chrome generic': 25,
#   'other': 26,
#   'chrome 59.0 for android': 27,
#   'firefox 56.0': 28,
#   'android webview 4.0': 29,
#   'chrome 55.0': 30,
#   'opera 49.0': 31,
#   'ie': 32,
#   'chrome 55.0 for android': 33,
#   'firefox 52.0': 34,
#   'chrome 57.0 for android': 35,
#   'chrome 56.0': 36,
#   'chrome 46.0 for android': 37,
#   'chrome 58.0': 38,
#   'firefox 48.0': 39,
#   'chrome 59.0': 40,
#   'samsung browser 4.0': 41,
#   'edge 13.0': 42,
#   'chrome 53.0 for android': 43,
#   'chrome 58.0 for android': 44,
#   'chrome 60.0': 45,
#   'mobile safari 8.0': 46,
#   'firefox generic': 47,
#   'Generic/Android 7.0': 48,
#   'mobile': 49,
#   'Samsung/SM-G532M': 50,
#   'chrome 50.0 for android': 51,
#   'chrome 51.0 for android': 52,
#   'chrome 63.0': 53,
#   'chrome 52.0 for android': 54,
#   'chrome 51.0': 55,
#   'firefox 55.0': 56,
#   'edge': 57,
#   'opera': 58,
#   'chrome generic for android': 59,
#   'aol': 60,
#   'samsung browser 5.4': 61,
#   'Samsung/SCH': 62,
#   'silk': 63,
#   'chrome 57.0': 64,
#   'firefox 47.0': 65,
#   'chrome 63.0 for android': 66,
#   'Samsung/SM-G531H': 67,
#   'chrome 43.0 for android': 68,
#   'waterfox': 69,
#   'Nokia/Lumia': 70,
#   'chrome 63.0 for ios': 71,
#   'puffin': 72,
#   'Microsoft/Windows': 73,
#   'cyberfox': 74,
#   'Generic/Android': 75,
#   'samsung': 76,
#   'opera generic': 77,
#   'chrome 49.0 for android': 78,
#   'ZTE/Blade': 79,
#   'safari': 80,
#   'android browser 4.0': 81,
#   'samsung browser 5.2': 82,
#   'palemoon': 83,
#   'maxthon': 84,
#   'line': 85,
#   'LG/K-200': 86,
#   'iron': 87,
#   'BLU/Dash': 88,
#   'seamonkey': 89,
#   'firefox 58.0': 90,
#   'chrome 64.0 for android': 91,
#   'chrome 64.0': 92,
#   'firefox 59.0': 93,
#   'chrome 64.0 for ios': 94,
#   'M4Tel/M4': 95,
#   'comodo': 96,
#   'Lanix/Ilium': 97,
#   'samsung browser generic': 98,
#   'chromium': 99,
#   'opera 51.0': 100,
#   'Inco/Minion': 101,
#   'samsung browser 7.0': 102,
#   'Mozilla/Firefox': 103,
#   'samsung browser 4.2': 104,
#   'samsung browser 6.4': 105,
#   'chrome 65.0': 106,
#   'chrome 65.0 for android': 107,
#   'chrome 65.0 for ios': 108,
#   'Cherry': 109,
#   'icedragon': 110,
#   'android': 111,
#   'edge 17.0': 112,
#   'chrome 66.0': 113,
#   'chrome 66.0 for android': 114,
#   'safari 11.0': 115,
#   'safari 9.0': 116,
#   'safari 10.0': 117,
#   'google': 118,
#   'chrome 66.0 for ios': 119,
#   'google search application 48.0': 120,
#   'opera 52.0': 121,
#   'firefox 60.0': 122,
#   'opera 53.0': 123,
#   'samsung browser 3.3': 124,
#   'google search application 49.0': 125,
#   'facebook': 126,
#   'firefox mobile 61.0': 127,
#   'chrome 67.0': 128,
#   'chrome 69.0': 129,
#   'chrome 67.0 for android': 130},
#  'id_33': {nan: 0,
#   '2220x1080': 1,
#   '1334x750': 2,
#   '1280x800': 3,
#   '1366x768': 4,
#   '1920x1080': 5,
#   '1680x1050': 6,
#   '1136x640': 7,
#   '5120x2880': 8,
#   '2880x1800': 9,
#   '1920x1200': 10,
#   '2560x1600': 11,
#   '2048x1536': 12,
#   '1024x768': 13,
#   '1280x720': 14,
#   '2560x1440': 15,
#   '2208x1242': 16,
#   '2001x1125': 17,
#   '1440x900': 18,
#   '1600x900': 19,
#   '2672x1440': 20,
#   '1280x1024': 21,
#   '960x540': 22,
#   '2732x2048': 23,
#   '2436x1125': 24,
#   '2048x1152': 25,
#   '2960x1440': 26,
#   '1024x600': 27,
#   '855x480': 28,
#   '4096x2304': 29,
#   '2160x1440': 30,
#   '2562x1442': 31,
#   '801x480': 32,
#   '2736x1824': 33,
#   '3441x1440': 34,
#   '2880x1620': 35,
#   '3840x2160': 36,
#   '1638x922': 37,
#   '1280x768': 38,
#   '1360x768': 39,
#   '1280x960': 40,
#   '3440x1440': 41,
#   '1152x720': 42,
#   '1280x1025': 43,
#   '3360x2100': 44,
#   '2304x1296': 45,
#   '1152x864': 46,
#   '3200x1800': 47,
#   '2112x1188': 48,
#   '2224x1668': 49,
#   '2400x1350': 50,
#   '2000x1125': 51,
#   '1600x1000': 52,
#   '2560x1080': 53,
#   '1728x972': 54,
#   '3000x2000': 55,
#   '1024x640': 56,
#   '3840x2400': 57,
#   '2304x1440': 58,
#   '1280x600': 59,
#   '1400x1050': 60,
#   '1600x1200': 61,
#   '3201x1800': 62,
#   '1356x900': 63,
#   '1344x756': 64,
#   '1624x1080': 65,
#   '1536x864': 66,
#   '1800x1125': 67,
#   '1920x1281': 68,
#   '2961x1442': 69,
#   '1366x1024': 70,
#   '1344x840': 71,
#   '3360x1890': 72,
#   '1536x1152': 73,
#   '1200x675': 74,
#   '1480x720': 75,
#   '2400x1600': 76,
#   '3200x2000': 77,
#   '1281x801': 78,
#   '960x640': 79,
#   '1776x1000': 80,
#   '2048x1280': 81,
#   '2049x1152': 82,
#   '1138x640': 83,
#   '2160x1215': 84,
#   '2880x1440': 85,
#   '0x0': 86,
#   '2520x1575': 87,
#   '5760x3240': 88,
#   '3843x2163': 89,
#   '1184x720': 90,
#   '1440x810': 91,
#   '2076x1080': 92,
#   '1600x837': 93,
#   '1093x615': 94,
#   '1281x721': 95,
#   '1152x648': 96,
#   '2392x1440': 97,
#   '2048x1080': 98,
#   '2735x1825': 99,
#   '1680x945': 100,
#   '1805x1015': 101,
#   '5760x1080': 102,
#   '2816x1584': 103,
#   '4500x3000': 104,
#   '1684x947': 105,
#   '1440x960': 106,
#   '1364x768': 107,
#   '3072x1728': 108,
#   '5040x3150': 109,
#   '7500x5000': 110,
#   '768x576': 111,
#   '1768x992': 112,
#   '1658x946': 113,
#   '1200x720': 114,
#   '1239x697': 115,
#   '1188x720': 116,
#   '1232x800': 117,
#   '1920x1280': 118,
#   '1264x924': 119,
#   '1400x900': 120,
#   '3240x2160': 121,
#   '2961x1440': 122,
#   '1422x889': 123,
#   '1848x1155': 124,
#   '3360x1050': 125,
#   '3840x1080': 126,
#   '2010x1080': 127,
#   '2160x1350': 128,
#   '1440x720': 129,
#   '1280x712': 130,
#   '1512x945': 131,
#   '1296x774': 132,
#   '1368x768': 133,
#   '3520x1980': 134,
#   '800x600': 135,
#   '1700x960': 136,
#   '2560x1800': 137,
#   '6400x3600': 138,
#   '2368x1440': 139,
#   '1824x1026': 140,
#   '1912x1025': 141,
#   '600x450': 142,
#   '3840x1600': 143,
#   '1760x990': 144,
#   '2700x1800': 145,
#   '1371x857': 146,
#   '1776x1080': 147,
#   '2552x1337': 148,
#   '3600x2250': 149,
#   '2560x1700': 150,
#   '2816x1760': 151,
#   '1440x800': 152,
#   '1440x803': 153,
#   '1920x1018': 154,
#   '6016x3384': 155,
#   '1280x620': 156,
#   '1281x720': 157,
#   '1720x1440': 158,
#   '1408x880': 159,
#   '640x360': 160,
#   '1920x975': 161,
#   '976x600': 162,
#   '1062x630': 163,
#   '2800x1575': 164,
#   '6720x3780': 165,
#   '1440x759': 166,
#   '1120x700': 167,
#   '1921x1081': 168,
#   '1280x1023': 169,
#   '1279x1023': 170,
#   '1441x901': 171,
#   '1679x1049': 172,
#   '1680x1051': 173,
#   '2220x1081': 174,
#   '1920x1079': 175,
#   '1919x1199': 176,
#   '1680x1049': 177,
#   '1365x768': 178,
#   '1919x1079': 179,
#   '1919x1200': 180,
#   '1919x1080': 181,
#   '1366x767': 182,
#   '1584x990': 183,
#   '2880x1442': 184,
#   '1281x800': 185,
#   '1229x691': 186,
#   '1600x1024': 187,
#   '1600x899': 188,
#   '1536x960': 189,
#   '1502x844': 190,
#   '1920x1201': 191,
#   '1439x809': 192,
#   '1408x792': 193,
#   '1279x1024': 194,
#   '1599x900': 195,
#   '1920x1081': 196,
#   '921x691': 197,
#   '3841x2161': 198,
#   '1921x1080': 199,
#   '480x320': 200,
#   '1888x941': 201,
#   '2049x1536': 202,
#   '2160x1439': 203,
#   '1707x960': 204,
#   '1024x767': 205,
#   '1365x767': 206,
#   '3001x2000': 207,
#   '3839x2160': 208,
#   '1916x901': 209,
#   '3838x2158': 210,
#   '1599x899': 211,
#   '3199x1800': 212,
#   '1511x944': 213,
#   '2737x1825': 214,
#   '2736x1823': 215,
#   '2735x1823': 216,
#   '2559x1439': 217,
#   '2400x1500': 218,
#   '2882x1442': 219,
#   '1729x973': 220,
#   '1727x971': 221,
#   '1023x767': 222,
#   '1918x1080': 223,
#   '1439x900': 224,
#   '4499x2999': 225,
#   '1280x740': 226,
#   '2999x2000': 227,
#   '1024x552': 228,
#   '1440x899': 229,
#   '2255x1503': 230,
#   '1025x768': 231,
#   '1280x732': 232,
#   '3839x2159': 233,
#   '3840x2162': 234,
#   '3696x2310': 235,
#   '2159x1439': 236,
#   '2256x1504': 237,
#   '1439x899': 238,
#   '2159x1440': 239,
#   '1359x768': 240,
#   '1092x614': 241,
#   '2048x1278': 242,
#   '2591x1619': 243,
#   '4200x2625': 244,
#   '2710x1440': 245,
#   '1272x960': 246,
#   '1023x768': 247,
#   '3838x2160': 248,
#   '2100x1312': 249,
#   '1360x767': 250,
#   '1024x819': 251,
#   '1502x845': 252,
#   '2561x1442': 253,
#   '2559x1440': 254,
#   '2160x1081': 255,
#   '1920x1279': 256,
#   '2160x1080': 257,
#   '1596x710': 258,
#   '1496x844': 259,
#   '1280x900': 260},
#  'id_34': {nan: 0,
#   'match_status:2': 1,
#   'match_status:1': 2,
#   'match_status:0': 3,
#   'match_status:-1': 4},
#  'id_35': {nan: 0, 'T': 1, 'F': 2},
#  'id_36': {nan: 0, 'F': 1, 'T': 2},
#  'id_37': {nan: 0, 'T': 1, 'F': 2},
#  'id_38': {nan: 0, 'T': 1, 'F': 2},
#  'DeviceType': {nan: 0, 'mobile': 1, 'desktop': 2},
#  'DeviceInfo': {nan: 0,
#   'SAMSUNG SM-G892A Build/NRD90M': 1,
#   'iOS Device': 2,
#   'Windows': 3,
#   'MacOS': 4,
#   'SM-G930V Build/NRD90M': 5,
#   'BLADE A602 Build/MRA58K': 6,
#   'XT1635-02 Build/NPN26.118-22-2': 7,
#   'Z970': 8,
#   'SM-N920V Build/NRD90M': 9,
#   'Redmi Note 4 Build/MMB29M': 10,
#   'Lenovo PB1-750M Build/S100': 11,
#   'LT22i Build/6.2.A.1.100': 12,
#   'rv:52.0': 13,
#   'SM-G950U Build/NRD90M': 14,
#   'LG-H872 Build/NRD90U': 15,
#   'LG-K500 Build/MMB29M': 16,
#   'SM-P550 Build/MMB29M': 17,
#   'SM-J700M Build/MMB29K': 18,
#   'Trident/7.0': 19,
#   'rv:57.0': 20,
#   'SAMSUNG SM-G930T Build/NRD90M': 21,
#   'Blade V6 Plus Build/MRA58K': 22,
#   'BLL-L23 Build/HUAWEIBLL-L23': 23,
#   'KYOCERA-C6742A Build/LMY47V': 24,
#   'F3113 Build/33.2.A.4.70': 25,
#   'D5306 Build/19.4.A.0.182': 26,
#   'M4 SS4457 Build/MRA58K': 27,
#   'SM-G955U Build/NRD90M': 28,
#   'SM-G610M Build/MMB29K': 29,
#   'SAMSUNG SM-G935F Build/NRD90M': 30,
#   'XT1635-01': 31,
#   'rv:56.0': 32,
#   'VS500': 33,
#   'CAM-L03 Build/HUAWEICAM-L03': 34,
#   'RCT6303W87M7 Build/MRA58K': 35,
#   'M4 SS4451 Build/LMY47D': 36,
#   'KFFOWI Build/LVY48F': 37,
#   'Moto E (4) Build/NMA26.42-19': 38,
#   'SAMSUNG': 39,
#   'E2306 Build/26.3.A.1.33': 40,
#   'Ilium L910 Build/MRA58K': 41,
#   'GT-I9300': 42,
#   'LG-H420 Build/LRX21Y': 43,
#   'Windows NT 6.2': 44,
#   'XT1032 Build/LPBS23.13-56-2': 45,
#   'GT-I9060M Build/KTU84P': 46,
#   'rv:38.0': 47,
#   'Moto G (4) Build/NPJS25.93-14-10': 48,
#   'SM-G530T': 49,
#   'LGMP260 Build/NRD90U': 50,
#   'SM-E500M Build/KTU84P': 51,
#   'SAMSUNG SM-G950U Build/NRD90M': 52,
#   'rv:11.0': 53,
#   'SM-G920I Build/NRD90M': 54,
#   'SAMSUNG SM-J327T Build/NRD90M': 55,
#   'SM-G900H Build/MMB29K': 56,
#   'TRT-L53 Build/HUAWEITRT-L53': 57,
#   'Android 6.0.1': 58,
#   'Moto G Play Build/MPIS24.241-15.3-26': 59,
#   'Nexus 6P Build/OPR5.170623.011': 60,
#   'SGP521': 61,
#   'VS988 Build/NRD90U': 62,
#   'SM-G531H Build/LMY48B': 63,
#   'Moto C Build/NRD90M.063': 64,
#   'LG-K410 Build/LRX22G': 65,
#   'SM-G935F Build/MMB29K': 66,
#   'Moto C Plus Build/NRD90M.05.022': 67,
#   'LG-X180g Build/LMY47I': 68,
#   'SM-G925P Build/NRD90M': 69,
#   'es-us': 70,
#   'SM-G920V Build/NRD90M': 71,
#   'SM-G935T Build/NRD90M': 72,
#   'Moto E (4) Plus Build/NMA26.42-69': 73,
#   'SM-G925W8': 74,
#   'rv:48.0': 75,
#   'SAMSUNG-SM-G930A Build/NRD90M': 76,
#   'HTC One M9 Build/NRD90M': 77,
#   '7055A Build/KVT49L': 78,
#   'Moto G Play Build/MPIS24.241-15.3-7': 79,
#   'SM-T810 Build/NRD90M': 80,
#   'rv:51.0': 81,
#   'SM-N910V Build/MMB29M': 82,
#   'SM-G930T Build/NRD90M': 83,
#   'LG-H870 Build/NRD90U': 84,
#   'SAMSUNG SM-G950U1 Build/NRD90M': 85,
#   'SAMSUNG SM-S727VL Build/MMB29M': 86,
#   'SM-N920G Build/NRD90M': 87,
#   'Moto G (5) Plus Build/NPN25.137-72': 88,
#   'Moto G (5) Build/NPP25.137-72': 89,
#   'SM-G935F Build/NRD90M': 90,
#   'LG-D373 Build/KOT49I.V10a': 91,
#   'ALE-L23 Build/HuaweiALE-L23': 92,
#   'Z836BL': 93,
#   'Ilium X710 Build/MRA58K': 94,
#   'LG-D680 Build/KOT49I': 95,
#   'M4 SS4450 Build/MRA58K': 96,
#   'LG-K580 Build/MRA58K': 97,
#   'SM-J700M Build/LMY48B': 98,
#   'SM-A710M': 99,
#   'Moto Z2 Play Build/NPSS26.118-19-6': 100,
#   'Moto G (4) Build/NPJ25.93-14.5': 101,
#   'Z981 Build/MMB29M': 102,
#   'SM-T710 Build/NRD90M': 103,
#   'SM-T700 Build/MMB29K': 104,
#   'ONE TOUCH 4033A Build/JDQ39': 105,
#   'F5121 Build/34.3.A.0.228': 106,
#   'WAS-LX3 Build/HUAWEIWAS-LX3': 107,
#   'R8106': 108,
#   'MotoG3 Build/MPIS24.65-33.1-2-16': 109,
#   'SM-G925I Build/MMB29K': 110,
#   'HUAWEI VNS-L53 Build/HUAWEIVNS-L53': 111,
#   'Blade V6 Build/LRX22G': 112,
#   'SM-T113NU Build/KTU84P': 113,
#   'SAMSUNG SM-G530H Build/LRX22G': 114,
#   'SM-J510MN Build/MMB29M': 115,
#   'SM-G950F Build/NRD90M': 116,
#   'SAMSUNG SM-J700M Build/MMB29K': 117,
#   'SM-G570M Build/MMB29K': 118,
#   'SAMSUNG-SM-G891A Build/NRD90M': 119,
#   'SM-J500M Build/LMY48B': 120,
#   'SM-J727U Build/NRD90M': 121,
#   'LGLS676 Build/MXB48T': 122,
#   'TA-1003': 123,
#   'SM-G900V Build/MMB29M': 124,
#   'VK810': 125,
#   'KFASWI Build/LVY48F': 126,
#   'SM-J320M Build/LMY47V': 127,
#   'SM-J120H Build/LMY47V': 128,
#   'SM-N950U Build/NMF26X': 129,
#   'LG-D693n Build/LRX22G': 130,
#   'HUAWEI RIO-L03 Build/HUAWEIRIO-L03': 131,
#   'SAMSUNG SM-G930A Build/NRD90M': 132,
#   '5012G Build/MRA58K': 133,
#   'SM-P350 Build/MMB29M': 134,
#   'SM-A300H Build/LRX22G': 135,
#   'Moto': 136,
#   'SM-G925V Build/NRD90M': 137,
#   'SAMSUNG SM-N910A Build/MMB29M': 138,
#   'SM-G532M Build/MMB29T': 139,
#   '5080A Build/MRA58K': 140,
#   'XT1254 Build/MCG24.251-5-5': 141,
#   'KFGIWI Build/LVY48F': 142,
#   'LG-D331 Build/LRX22G': 143,
#   'SM-G950U1 Build/NRD90M': 144,
#   'Pixel': 145,
#   'SM-G900T Build/MMB29M': 146,
#   'E5606 Build/30.2.A.1.21': 147,
#   'Moto Z2 Play Build/NPS26.74-16-1': 148,
#   'Z410': 149,
#   'LG-H500 Build/LRX21Y': 150,
#   'HUAWEI TAG-L13 Build/HUAWEITAG-L13': 151,
#   'P4526A Build/NRD90M': 152,
#   'SM-G900F Build/MMB29M': 153,
#   'Moto G (4) Build/NPJ25.93-14.7': 154,
#   'SM-A510M Build/NRD90M': 155,
#   'XT1565': 156,
#   'Blade V6 Max Build/MRA58K': 157,
#   'F3213 Build/36.1.A.1.86': 158,
#   'REX': 159,
#   'Pixel Build/OPR3.170623.013': 160,
#   'XT1585 Build/NCK25.118-10.5': 161,
#   'MotoG3-TE': 162,
#   'Ilium LT510 Build/MRA58K': 163,
#   'SAMSUNG-SM-G870A Build/MMB29M': 164,
#   'SM-A500M Build/KTU84P': 165,
#   'HTC': 166,
#   'SAMSUNG SM-G950F Build/NRD90M': 167,
#   'LG-X240 Build/MRA58K': 168,
#   'KFAUWI Build/LVY48F': 169,
#   'LG-K428 Build/MMB29M': 170,
#   'SAMSUNG SM-T580 Build/NRD90M': 171,
#   'Edison': 172,
#   'Hisense F20 Build/MMB29M': 173,
#   'SM-J327V Build/NRD90M': 174,
#   'LGLS775 Build/NRD90U': 175,
#   'SM-A710M Build/LMY47X': 176,
#   'LG-LS777 Build/NRD90U': 177,
#   'LG-H320 Build/LRX21Y': 178,
#   'QTASUN1 Build/NRD90M': 179,
#   'SM-J730G Build/NRD90M': 180,
#   'rv:58.0': 181,
#   'HTC 10 Build/NRD90M': 182,
#   'XT1063': 183,
#   'VS995 Build/NRD90M': 184,
#   'SM-G550T Build/MMB29K': 185,
#   'SAMSUNG SM-G930P Build/NRD90M': 186,
#   'LG-K530 Build/MMB29M': 187,
#   'SAMSUNG SM-J701M Build/NRD90M': 188,
#   'SAMSUNG SM-T587P Build/NRD90M': 189,
#   'SM-T530NU Build/LRX22G': 190,
#   'SM-S920L': 191,
#   'SM-G530H Build/LRX22G': 192,
#   'LG-V410': 193,
#   'SAMSUNG SM-G891A Build/NRD90M': 194,
#   'GT-P5113': 195,
#   'LG-H840 Build/NRD90U': 196,
#   'BAC-L03 Build/HUAWEIBAC-L03': 197,
#   'SAMSUNG SM-T810 Build/NRD90M': 198,
#   'VS835': 199,
#   'LG-TP450 Build/NRD90U': 200,
#   'SM-J727V Build/NRD90M': 201,
#   'SM-G955F Build/NRD90M': 202,
#   'KFDOWI Build/LVY48F': 203,
#   'SM-J200M Build/LMY47X': 204,
#   'SM-J320H': 205,
#   'BLADE V8 SE Build/NRD90M': 206,
#   'SM-N920T Build/NRD90M': 207,
#   'LG-H542 Build/MRA58K': 208,
#   'SM-T330NU Build/LMY47X': 209,
#   'SAMSUNG SM-J500M Build/LMY48B': 210,
#   'LG-M322': 211,
#   'CHC-U03 Build/HuaweiCHC-U03': 212,
#   'HTC Desire 650 Build/MMB29M': 213,
#   'SAMSUNG-SM-G935A Build/NRD90M': 214,
#   'SM-G925I Build/NRD90M': 215,
#   'LG-K200 Build/MXB48T': 216,
#   'Aquaris': 217,
#   'SM-J710MN Build/MMB29K': 218,
#   'Alcatel_4060A': 219,
#   'LGMS631 Build/MRA58K': 220,
#   'MOT-A6020l37 Build/LMY47V': 221,
#   '5011A Build/NRD90M': 222,
#   'SM-T550 Build/NMF26X': 223,
#   'Moto G (5) Plus Build/NPNS25.137-15-11': 224,
#   'E6603 Build/32.4.A.1.54': 225,
#   'Redmi 4A Build/MMB29M': 226,
#   'rv:55.0': 227,
#   'SM-T520': 228,
#   'HTC Desire 10 lifestyle Build/MMB29M': 229,
#   'SM-A720F Build/MMB29K': 230,
#   'Moto G (5S': 231,
#   'SM-G925I Build/LMY47X': 232,
#   'SM-G930R4 Build/NRD90M': 233,
#   'SAMSUNG SM-G610M Build/MMB29K': 234,
#   'Lenovo K33b36 Build/NRD90N': 235,
#   'SM-G930U Build/NRD90M': 236,
#   'Moto Z2 Play Build/NPS26.118-19': 237,
#   'SAMSUNG SM-N950U Build/NMF26X': 238,
#   'SM-A320FL Build/MMB29K': 239,
#   'LG-M250 Build/NRD90U': 240,
#   'KFSAWI': 241,
#   'SAMSUNG SM-G930F Build/NRD90M': 242,
#   'Lenovo K33b36 Build/MMB29M': 243,
#   'SAMSUNG SM-N920V Build/NRD90M': 244,
#   'Windows NT 6.1': 245,
#   'rv:45.0': 246,
#   'SAMSUNG-SM-J327A Build/NRD90M': 247,
#   'SM-G935V Build/NRD90M': 248,
#   'MDDRJS': 249,
#   'SM-G935P Build/NRD90M': 250,
#   'SM-G930P Build/NRD90M': 251,
#   'SM-G928V Build/NRD90M': 252,
#   'LG-M210 Build/NRD90U': 253,
#   'Blade V580 Build/LMY47D': 254,
#   'Ilium LT500 Build/LMY47O': 255,
#   'Y635-L03 Build/HuaweiY635-L03': 256,
#   'XT1635-01 Build/NDNS26.118-23-12-3': 257,
#   'rv:42.0': 258,
#   'SAMSUNG SM-G925T Build/NRD90M': 259,
#   'SAMSUNG-SM-G900A Build/LRX21T': 260,
#   'Moto Z (2': 261,
#   'SM-G360T1 Build/LMY47X': 262,
#   'SM-S903VL': 263,
#   'SAMSUNG SM-G920A Build/NRD90M': 264,
#   'HUAWEI VNS-L23 Build/HUAWEIVNS-L23': 265,
#   'LG-H811 Build/MRA58K': 266,
#   'M4 SS4456 Build/LMY47V': 267,
#   'SAMSUNG-SM-T337A Build/LMY47X': 268,
#   'SAMSUNG SM-G955U Build/NRD90M': 269,
#   'SM-G900P Build/MMB29M': 270,
#   'SM-G800F Build/KOT49H': 271,
#   'BNTV400': 272,
#   'HUAWEI VNS-L21 Build/HUAWEIVNS-L21': 273,
#   'ONEPLUS A5000 Build/NMF26X': 274,
#   'HTC Desire 626s Build/LMY47O': 275,
#   'Android 4.4.2': 276,
#   'XT1710-02 Build/NDSS26.118-23-15': 277,
#   'rv:49.0': 278,
#   'EVA-L09 Build/HUAWEIEVA-L09': 279,
#   'Lenovo': 280,
#   'LG-K540 Build/MMB29M': 281,
#   'FRD-L04 Build/HUAWEIFRD-L04': 282,
#   'Linux x86_64': 283,
#   'SAMSUNG SM-G935T Build/NRD90M': 284,
#   'SM-G900M Build/LRX21T': 285,
#   'LG-H820 Build/NRD90U': 286,
#   'Z983 Build/NMF26F': 287,
#   'LGLS991': 288,
#   'SM-S120VL': 289,
#   'Le': 290,
#   'Ilium L1120 Build/NRD90M': 291,
#   'XT1650 Build/NCLS26.118-23-13-3': 292,
#   'SM-T377P Build/NMF26X': 293,
#   'QTAQZ3 Build/LMY47V': 294,
#   'SM-A310M': 295,
#   'F5321': 296,
#   'KFTBWI Build/LVY48F': 297,
#   'M4 SS4453 Build/MMB29M': 298,
#   'XT1064 Build/MPB24.65-34-3': 299,
#   'VS987 Build/NRD90U': 300,
#   'SM-G386T': 301,
#   'SAMSUNG-SM-N920A Build/NRD90M': 302,
#   'SAMSUNG SM-J727T1 Build/NRD90M': 303,
#   'SAMSUNG SM-G532M Build/MMB29T': 304,
#   'SM-G925T Build/NRD90M': 305,
#   'NetHelper70': 306,
#   'SAMSUNG SM-G890A Build/NRD90M': 307,
#   'D5803 Build/23.5.A.1.291': 308,
#   'GT-I8190L Build/JZO54K': 309,
#   'SM-A510M Build/LMY47X': 310,
#   'Nexus': 311,
#   'SM-T580 Build/NRD90M': 312,
#   'SM-G900V': 313,
#   'ZEIA8': 314,
#   'SM-N920P Build/NRD90M': 315,
#   'SM-T550': 316,
#   'SAMSUNG SM-J320F Build/LMY47V': 317,
#   'VS501 Build/NRD90U': 318,
#   'Linux i686': 319,
#   'SM-G900P Build/LRX21T': 320,
#   'SM-N910H': 321,
#   'SM-G920F Build/NRD90M': 322,
#   'SM-T560 Build/KTU84P': 323,
#   'MotoE2(4G-LTE': 324,
#   'LG-H542 Build/LRX22G': 325,
#   'Touch': 326,
#   'Moto G (5) Build/NPP25.137-82': 327,
#   'LG-X230 Build/MRA58K': 328,
#   'LG-K371': 329,
#   'F3113 Build/33.3.A.1.97': 330,
#   'SM-T560NU Build/MMB29M': 331,
#   'SAMSUNG SM-A520F Build/NRD90M': 332,
#   'SM-P600 Build/LMY47X': 333,
#   'HTC U11 Build/NMF26X': 334,
#   'KFAPWI Build/KTU84M': 335,
#   'G3313': 336,
#   'AX920': 337,
#   'SM-J327VPP Build/NRD90M': 338,
#   'LG-M320 Build/NRD90U': 339,
#   'SM-G610F': 340,
#   'rv:54.0': 341,
#   'QMV7A': 342,
#   'SM-T817V Build/NRD90M': 343,
#   'HTC Desire 530 Build/MMB29M': 344,
#   'LG-LS998': 345,
#   'rv:41.0': 346,
#   'GT-P5210 Build/JDQ39': 347,
#   'SM-J730F': 348,
#   'KFJWI': 349,
#   'Moto G (5) Plus Build/NPN25.137-83': 350,
#   'HTC Desire 510 Build/KOT49H': 351,
#   'Android': 352,
#   'LG-H810': 353,
#   'SM-G920P Build/NRD90M': 354,
#   'D6603 Build/23.5.A.1.291': 355,
#   'XT1650': 356,
#   'SM-G930F Build/NRD90M': 357,
#   'LGMS550 Build/NRD90U': 358,
#   'moto': 359,
#   'SM-A520F Build/NRD90M': 360,
#   'SM-G920T Build/NRD90M': 361,
#   'Fractal': 362,
#   'Moto E (4) Build/NMA26.42-69': 363,
#   'HUAWEI': 364,
#   'SM-T350 Build/NMF26X': 365,
#   'SAMSUNG SM-J730GM Build/NRD90M': 366,
#   'TA-1039 Build/N2G47H': 367,
#   'XT1003': 368,
#   'MotoG3 Build/MPIS24.65-25.1-19': 369,
#   'BV6000': 370,
#   'SM-T230 Build/KOT49H': 371,
#   'SAMSUNG SM-G920P Build/NRD90M': 372,
#   'HTC One A9 Build/NRD90M': 373,
#   'NX785QC8G': 374,
#   'rv:47.0': 375,
#   'E5506 Build/29.1.A.0.101': 376,
#   'LGL33L/V100': 377,
#   'SM-G920V Build/MMB29K': 378,
#   'SM-J510FN': 379,
#   'LGMS330 Build/LMY47V': 380,
#   'Microsoft': 381,
#   'SM-T560NU Build/NMF26X': 382,
#   'SAMSUNG SM-G955F Build/NRD90M': 383,
#   'XT1053 Build/LPAS23.12-21.7-1': 384,
#   '5025G Build/LMY47I': 385,
#   'LG-H918 Build/NRD90M': 386,
#   'SM-G900W8': 387,
#   'SM-J320V Build/NMF26X': 388,
#   'SM-J105B Build/LMY47V': 389,
#   'SAMSUNG SM-G550T1 Build/MMB29K': 390,
#   '5010S Build/MRA58K': 391,
#   'LG-H910 Build/NRD90M': 392,
#   'MotoE2 Build/LPCS23.13-56-5': 393,
#   'LGMS210 Build/NRD90U': 394,
#   'LG-M700 Build/NMF26X': 395,
#   'SM-G930V Build/MMB29M': 396,
#   'SM-A510M Build/MMB29K': 397,
#   '5054N': 398,
#   'SAMSUNG SM-G900A Build/MMB29M': 399,
#   'SM-G935V': 400,
#   'SAMSUNG-SM-T677A': 401,
#   'SM-J500FN': 402,
#   'LGMP450 Build/NRD90U': 403,
#   'Pixel 2 Build/OPM1.171019.011': 404,
#   'SM-J701M Build/NRD90M': 405,
#   'Z798BL Build/MMB29M': 406,
#   'HUAWEI CUN-L03 Build/HUAWEICUN-L03': 407,
#   'Lenovo-A6020l36 Build/LMY47V': 408,
#   'VS820': 409,
#   'KFTHWI Build/KTU84M': 410,
#   'LG-K530 Build/NRD90U': 411,
#   'SM-T827V Build/NRD90M': 412,
#   'SAMSUNG SM-G935F Build/MMB29K': 413,
#   'LG-H650 Build/MRA58K': 414,
#   'SAMSUNG-SGH-I337 Build/KOT49H': 415,
#   'LG-K220 Build/MXB48T': 416,
#   'LG-H810/H81021z': 417,
#   'ALE-L21 Build/HuaweiALE-L21': 418,
#   'Redmi 4X Build/N2G47H': 419,
#   'SAMSUNG SM-G935A Build/NRD90M': 420,
#   'SM-T713 Build/NRD90M': 421,
#   '5051A Build/MMB29M': 422,
#   'LG-P714': 423,
#   'SAMSUNG SM-G531H Build/LMY48B': 424,
#   'SM-G928G Build/NRD90M': 425,
#   'X10': 426,
#   'GT-P5210 Build/KOT49H': 427,
#   'GT-I9500': 428,
#   'HUAWEI Y625-U13 Build/HUAWEIY625-U13': 429,
#   'Hisense L675 Build/MRA58K': 430,
#   'P5526A Build/NRD90M': 431,
#   'SM-T818V': 432,
#   'es-mx': 433,
#   'TA-1039 Build/NMF26F': 434,
#   'SM-A310M Build/LMY47X': 435,
#   'LG-D851': 436,
#   'SM-J320V Build/MMB29M': 437,
#   'LG-H990 Build/NRD90M': 438,
#   'LG-V495/V49520l': 439,
#   'SM-T350 Build/MMB29M': 440,
#   'PRA-LX3 Build/HUAWEIPRA-LX3': 441,
#   'XT1080 Build/SU6-7.7': 442,
#   'HUAWEI Y520-U03 Build/HUAWEIY520-U03': 443,
#   'Lenovo A2016b30 Build/MRA58K': 444,
#   'MYA-L23': 445,
#   'K88 Build/MMB29M': 446,
#   'MotoG3 Build/MPIS24.107-55-2-17': 447,
#   'LGLS770': 448,
#   'LG-M153 Build/MXB48T': 449,
#   'QTAIR7 Build/LMY47D': 450,
#   '2PQ93': 451,
#   'SM-J111M Build/LMY47V': 452,
#   'SM-S320VL': 453,
#   'LG-H901': 454,
#   'ILIUM': 455,
#   'SM-T377V Build/NMF26X': 456,
#   'ONE A2005 Build/MMB29M': 457,
#   'SM-N910T Build/MMB29M': 458,
#   'Android 5.1': 459,
#   'XT1058 Build/LPAS23.12-21.7-1': 460,
#   'Pixel Build/OPM1.171019.011': 461,
#   'Pixel XL Build/OPM1.171019.011': 462,
#   'LG-TP260 Build/NRD90U': 463,
#   'SM-N900V Build/LRX21V': 464,
#   'Moto X Play Build/NPD26.48-24-1': 465,
#   'SKY_5.0LM': 466,
#   'SM-A320Y Build/NRD90M': 467,
#   'SM-T230NU Build/KOT49H': 468,
#   'KFTT Build/IML74K': 469,
#   '2PS64 Build/NRD90M': 470,
#   'SAMSUNG-SM-G930A': 471,
#   'STV100-2 Build/MMB29M': 472,
#   'G3123 Build/40.0.A.6.135': 473,
#   'SAMSUNG SM-A300H Build/LRX22G': 474,
#   'Z971': 475,
#   'SM-G935W8': 476,
#   'SM-P580 Build/NRD90M': 477,
#   'SAMSUNG-SM-J320A Build/MMB29K': 478,
#   'SAMSUNG-SM-J727A Build/NRD90M': 479,
#   'VerykoolS5030': 480,
#   'SM-J320P Build/LMY47X': 481,
#   'LGLS751': 482,
#   'F8331 Build/41.2.A.7.76': 483,
#   'SM-A520F Build/MMB29K': 484,
#   'Blade L5 Build/LMY47I': 485,
#   'TOMMY2': 486,
#   'rv:50.0': 487,
#   'SLA-L03 Build/HUAWEISLA-L03': 488,
#   'Moto E (4) Build/NMA26.42-11-3': 489,
#   'SM-T280 Build/LMY47V': 490,
#   'F8331': 491,
#   'Z837VL': 492,
#   'SM-A510F Build/NRD90M': 493,
#   'XT1580': 494,
#   'SM-T820 Build/NRD90M': 495,
#   'SM-G550T1 Build/MMB29K': 496,
#   'LG-H871': 497,
#   'LG-LS993 Build/NRD90U': 498,
#   'SM-T377W': 499,
#   'SAMSUNG SM-J700M Build/LMY48B': 500,
#   'SM-G900F Build/LRX21T': 501,
#   'SAMSUNG-SM-G900A Build/MMB29M': 502,
#   'XT1032 Build/KXB21.14-L1.40': 503,
#   'XT1563 Build/MPDS24.107-52-5': 504,
#   'Blade': 505,
#   'verykoolS5019': 506,
#   'SM-G360V Build/LMY48B': 507,
#   'LG-X210 Build/LMY47I': 508,
#   'hi6210sft Build/MRA58K': 509,
#   'SAMSUNG SM-T530NU Build/LRX22G': 510,
#   'C6743 Build/LMY47V': 511,
#   'BLN-L24 Build/HONORBLN-L24': 512,
#   'SM-G935T': 513,
#   'Redmi Note 3 Build/MMB29M': 514,
#   'SAMSUNG-SM-G900A Build/LMY47X': 515,
#   'E6810 Build/5.320VZ.03.r': 516,
#   'E6553': 517,
#   'Pixel 2 XL Build/OPM1.171019.011': 518,
#   'Z835 Build/NMF26V': 519,
#   'LG-D725': 520,
#   'XT1008 Build/LPBS23.13-56-2': 521,
#   'XT1040': 522,
#   'en-us': 523,
#   'SM-T807V': 524,
#   'VS996': 525,
#   'E6853': 526,
#   'LG-K550 Build/NRD90U': 527,
#   'XT1030 Build/SU6-7.7': 528,
#   'LG-M154': 529,
#   'SM-J700T Build/NMF26X': 530,
#   'SM-G920F Build/MMB29K': 531,
#   '8050G Build/LMY47I': 532,
#   'SM-A500FU Build/MMB29M': 533,
#   'SM-T337V': 534,
#   'SAMSUNG-SM-T377A Build/MMB29K': 535,
#   'HELIO': 536,
#   'BLADE V7 Build/MRA58K': 537,
#   'MotoG3 Build/MPI24.65-33.1-2': 538,
#   'SM-N950F Build/NMF26X': 539,
#   'LGMS550 Build/MXB48T': 540,
#   'XT1031': 541,
#   'SAMSUNG SM-T710 Build/NRD90M': 542,
#   'Lenovo TB-7703X Build/S100': 543,
#   'Moto G (5) Build/NPPS25.137-15-11': 544,
#   'LT30p': 545,
#   'Moto G (4) Build/NPJ25.93-14': 546,
#   'MHA-L09 Build/HUAWEIMHA-L09': 547,
#   'HUAWEI VNS-L31 Build/HUAWEIVNS-L31': 548,
#   'Hisense L675 PRO Build/NRD90M': 549,
#   'SAMSUNG-SM-G925A Build/NRD90M': 550,
#   'Mi A1 Build/N2G47H': 551,
#   'SM-N900T': 552,
#   'VS425PP Build/LMY47V': 553,
#   'SM-J727T Build/NRD90M': 554,
#   'LG-X220 Build/LMY47I': 555,
#   'ATT-IE11': 556,
#   'SAMSUNG SM-G900F Build/MMB29M': 557,
#   'BLADE V8 Build/NRD90M': 558,
#   'SM-J700T1 Build/NMF26X': 559,
#   'SM-G930R7': 560,
#   'LGUS215 Build/NRD90U': 561,
#   'SM-T237P': 562,
#   'TA-1038': 563,
#   'SM-G930W8 Build/NRD90M': 564,
#   'SM-G950W': 565,
#   'SM-J100VPP Build/LMY48B': 566,
#   'LGLS990': 567,
#   'SM-A500H': 568,
#   'F3313 Build/37.0.A.2.108': 569,
#   'SM-G900I': 570,
#   'SM-T813 Build/NRD90M': 571,
#   'rv:31.0': 572,
#   'SM-J730GM Build/NRD90M': 573,
#   'H1711 Build/HUAWEIH1711': 574,
#   'Build/OPR6.170623.013': 575,
#   'LG-V930': 576,
#   'LG-K240 Build/MXB48T': 577,
#   'Z982 Build/NMF26V': 578,
#   'SAMSUNG SM-J700T Build/NMF26X': 579,
#   'rv:44.0': 580,
#   'XT1055': 581,
#   'Moto E (4) Build/NCQ26.69-56': 582,
#   'Moto E (4) Build/NDQS26.69-23-2-3': 583,
#   'XT1575': 584,
#   'SM-J327P Build/MMB29M': 585,
#   'SM-T377V': 586,
#   'HUAWEI G7-L03 Build/HuaweiG7-L03': 587,
#   'LG-D693n Build/KOT49I.V10a': 588,
#   'SM-P900': 589,
#   'SM-J500M Build/MMB29M': 590,
#   'SAMSUNG SM-N920T Build/NRD90M': 591,
#   'Blade A510 Build/MRA58K': 592,
#   'LGL62VL': 593,
#   'BBB100-3': 594,
#   'SM-N910C Build/MMB29K': 595,
#   'LG-LS997 Build/NRD90M': 596,
#   'SM-N950W': 597,
#   '4027A Build/KOT49H': 598,
#   'rv:53.0': 599,
#   'E2306 Build/26.1.A.3.111': 600,
#   'ZTE': 601,
#   'LG-M150': 602,
#   'HTC One Build/LRX22G': 603,
#   'SAMSUNG SM-G925P Build/NRD90M': 604,
#   'SAMSUNG SM-G570M Build/MMB29K': 605,
#   'LG-H830 Build/NRD90U': 606,
#   'SAMSUNG SM-N920P Build/NRD90M': 607,
#   'SAMSUNG-SM-G890A Build/MMB29K': 608,
#   'SAMSUNG SM-G920T Build/NRD90M': 609,
#   'SAMSUNG SM-N920A Build/NRD90M': 610,
#   'rv:46.0': 611,
#   'SM-T800 Build/MMB29K': 612,
#   'hp2015': 613,
#   'Moto G (5) Build/NPP25.137-38': 614,
#   'SAMSUNG SM-G903F Build/MMB29K': 615,
#   'SM-J100MU': 616,
#   'E6833': 617,
#   'SM-G920W8': 618,
#   '5010G Build/MRA58K': 619,
#   'A3_mini': 620,
#   'XT1528': 621,
#   'rv:39.0': 622,
#   'SM-N900W8 Build/LRX21V': 623,
#   'SM-G920T1': 624,
#   'HP': 625,
#   'SM-S820L': 626,
#   'XT1032 Build/LPBS23.13-57-2': 627,
#   'SM-G920V': 628,
#   'SAMSUNG SM-G850F/G850FXXS2CQD9 Build/LRX22G': 629,
#   'LG-H850': 630,
#   'Redmi': 631,
#   'D6708': 632,
#   'LG-H900/H90022b': 633,
#   'SAMSUNG-SM-G920A Build/NRD90M': 634,
#   'HUAWEI CAN-L01 Build/HUAWEICAN-L01': 635,
#   'SAMSUNG SM-G935P Build/NRD90M': 636,
#   'WOW64': 637,
#   'SAMSUNG SM-J327T1 Build/NRD90M': 638,
#   'XT1563 Build/MPD24.107-52': 639,
#   'CRO-L03 Build/HUAWEICRO-L03': 640,
#   'Hisense F23 Build/NRD90M': 641,
#   'Moto C Plus Build/NRD90M.05.034': 642,
#   'Redmi Note 4 Build/NRD90M': 643,
#   'LG-K373': 644,
#   'SM-G530P': 645,
#   'SM-J320FN Build/LMY47V': 646,
#   'moto x4 Build/NPW26.83-18-2-0-4': 647,
#   'F5121 Build/34.3.A.0.238': 648,
#   'Android 5.1.1': 649,
#   'Ilium X210 Build/LMY47I': 650,
#   'HTC6545LVW': 651,
#   'SM-S902L': 652,
#   'C2104': 653,
#   'SAMSUNG-SM-T537A': 654,
#   'VS990 Build/MRA58K': 655,
#   'SM-N920V': 656,
#   '5056A Build/MMB29M': 657,
#   'Lenovo A6020l37 Build/LMY47V': 658,
#   'SAMSUNG-SM-G928A Build/NRD90M': 659,
#   'PH-1': 660,
#   'G3423': 661,
#   'E5803 Build/32.4.A.1.54': 662,
#   'Hisense U963 Build/MRA58K': 663,
#   'moto x4 Build/NPW26.83-42': 664,
#   'F3113 Build/33.2.A.3.81': 665,
#   'HTC One_M8 Build/MRA58K': 666,
#   'SAMSUNG SM-G530T Build/LMY47X': 667,
#   'SM-G530H Build/KTU84P': 668,
#   'SM-P355M Build/MMB29M': 669,
#   'ONE TOUCH 4016A Build/JDQ39': 670,
#   'Ilium X510 Build/MRA58K': 671,
#   'BLADE A520 Build/NRD90M': 672,
#   'VS986 Build/MRA58K': 673,
#   'XT1609 Build/MPIS24.241-2.35-1-17': 674,
#   'SAMSUNG-SM-G890A': 675,
#   'LG-D855 Build/LRX21R': 676,
#   'LG-H631': 677,
#   'FP2': 678,
#   'GT-N5110': 679,
#   'm3': 680,
#   'G3313 Build/43.0.A.5.79': 681,
#   'SM-G955U1 Build/NRD90M': 682,
#   'SM-J530GM Build/NRD90M': 683,
#   'XT1563': 684,
#   'KFSUWI Build/LVY48F': 685,
#   'R1': 686,
#   'Blade L2 Plus Build/KOT49H': 687,
#   'SAMSUNG SM-G925F Build/NRD90M': 688,
#   'XT1635-02': 689,
#   'LG-V521': 690,
#   'TA-1038 Build/NMF26O': 691,
#   'SCH-I435': 692,
#   'SM-G928T Build/NRD90M': 693,
#   'P027': 694,
#   '5054S Build/LMY47V': 695,
#   'MotoG3-TE Build/MPDS24.65-33-1-30': 696,
#   'XT1064': 697,
#   'SM-J327T1 Build/NRD90M': 698,
#   'P00C': 699,
#   'SAMSUNG SM-G920F Build/NRD90M': 700,
#   'LG-H840 Build/MMB29M': 701,
#   'Lenovo TB-X103F Build/LenovoTB-X103F': 702,
#   'REVVLPLUS': 703,
#   'LG-M430 Build/NRD90U': 704,
#   'XT1060': 705,
#   'HUAWEI NXT-L09 Build/HUAWEINXT-L09': 706,
#   'LenovoA3300-GV Build/JDQ39': 707,
#   'rv:35.0': 708,
#   'KFMEWI': 709,
#   'Le X520 Build/IEXCNFN5902303111S': 710,
#   'Nexus 6P Build/OPR5.170623.014': 711,
#   'LG-M327 Build/NRD90U': 712,
#   'SAMSUNG-SM-G890A Build/NRD90M': 713,
#   'PSPC550 Build/LMY47D': 714,
#   'SM-G930VL Build/NRD90M': 715,
#   'STV100-3': 716,
#   'SAMSUNG SM-N950U1 Build/NMF26X': 717,
#   'SM-A320Y': 718,
#   'SAMSUNG SM-A720F Build/NRD90M': 719,
#   'SM-G355M Build/KOT49H': 720,
#   'ME173X': 721,
#   'GT-S7580L Build/JDQ39': 722,
#   'ALCATEL': 723,
#   'NXA116QC164': 724,
#   'ZTE Blade L5 Build/LMY47I': 725,
#   'SM-G360V': 726,
#   'SM-G925F Build/NRD90M': 727,
#   'AX820 Build/MRA58K': 728,
#   'SM-G360M': 729,
#   'V.40R': 730,
#   'BLU': 731,
#   'MALC': 732,
#   'SM-G928V Build/MMB29K': 733,
#   'ASUS_Z00ED': 734,
#   'SH-04F': 735,
#   'TREKKER-X3 Build/MMB29M': 736,
#   'BLADE L7 Build/MRA58K': 737,
#   'Nexus 5 Build/M4B30Z': 738,
#   'Venue': 739,
#   'SAMSUNG SM-J327A Build/NRD90M': 740,
#   'SM-T310 Build/KOT49H': 741,
#   'Android 7.0': 742,
#   'SM-A310F Build/MMB29K': 743,
#   'Moto G (4) Build/NPJS25.93-14-8': 744,
#   'Moto E (4) Plus Build/NMA26.42-11-3': 745,
#   'VS880PP': 746,
#   'S.N.O.W.4': 747,
#   'SM-J727T1 Build/NRD90M': 748,
#   'SAMSUNG-SM-N900A': 749,
#   'SAMSUNG SM-G900T Build/MMB29M': 750,
#   'SGH-I337M Build/LRX22C': 751,
#   'SM-N900T Build/LRX21V': 752,
#   'MAMI': 753,
#   'M4': 754,
#   'SM-N9005 Build/LRX21V': 755,
#   'TREKKER-M1': 756,
#   'SCH-I535': 757,
#   'LG-V496': 758,
#   'NOKIA': 759,
#   'SGH-I317M': 760,
#   'Turbo C5 Build/LMY47I': 761,
#   'E5506 Build/29.2.A.0.166': 762,
#   'LG-H540': 763,
#   'LG-D855': 764,
#   'Z963VL': 765,
#   'SAMSUNG SM-J327P Build/MMB29M': 766,
#   'VFD': 767,
#   'SM-S906L': 768,
#   'HUAWEI Y560-L03 Build/HUAWEIY560-L03': 769,
#   'PRA-LX1 Build/HUAWEIPRA-LX1': 770,
#   'LG-H443/H44312g': 771,
#   'Lenovo TB2-X30F Build/LenovoTB2-X30F': 772,
#   '2PYB2': 773,
#   'HTC One A9s Build/MRA58K': 774,
#   'LG-K450 Build/MXB48T': 775,
#   'SM-N950U1 Build/NMF26X': 776,
#   'ZTE-Z835': 777,
#   'XT1033': 778,
#   'SM-G900R4': 779,
#   'LG-K430 Build/MRA58K': 780,
#   'G8141 Build/47.1.A.5.51': 781,
#   'Z956 Build/MMB29M': 782,
#   'VS880': 783,
#   '5049W Build/NRD90M': 784,
#   'BLA-L29 Build/HUAWEIBLA-L29': 785,
#   '5057M': 786,
#   'K88': 787,
#   'Blade A460 Build/LMY47O': 788,
#   'BLU LIFE XL Build/L050U': 789,
#   'Coolpad': 790,
#   'Vivo': 791,
#   'SM-G930T1': 792,
#   '2PZC5': 793,
#   'SM-T113 Build/KTU84P': 794,
#   'ATT': 795,
#   'Studio': 796,
#   'Z959 Build/LMY47V': 797,
#   'ZTE BLADE A321 Build/NMF26F': 798,
#   'HTC6535LVW': 799,
#   'MotoG3 Build/MPI24.65-25': 800,
#   'LG-X165g Build/LRX21M': 801,
#   'SM-J327T Build/NRD90M': 802,
#   'SLAY': 803,
#   'orbis': 804,
#   'SAMSUNG SM-G925I Build/NRD90M': 805,
#   'S57 Build/KTU84P': 806,
#   'SAMSUNG SM-A510M Build/NRD90M': 807,
#   'SM-A500M Build/LRX22G': 808,
#   'SAMSUNG SM-J111M Build/LMY47V': 809,
#   'SCH-I545 Build/LRX22C': 810,
#   'LG-H345': 811,
#   'SM-S907VL': 812,
#   'SAMSUNG-SM-G870A': 813,
#   'SM-J727VPP Build/NRD90M': 814,
#   'LGL58VL': 815,
#   'SAMSUNG SM-P580 Build/NRD90M': 816,
#   '9003A Build/MRA58K': 817,
#   'Moto G (5) Plus Build/NPN25.137-82': 818,
#   'LG-M400 Build/NRD90U': 819,
#   'XT1058': 820,
#   'HTC6525LVW': 821,
#   'FRD-L14 Build/HUAWEIFRD-L14': 822,
#   'XT1096': 823,
#   'QwestIE8': 824,
#   'SAMSUNG-SM-T817A': 825,
#   'ASUS': 826,
#   'LG-D331': 827,
#   'LG-M255': 828,
#   'SM-G928F': 829,
#   'verykoolS5525': 830,
#   'KFSOWI': 831,
#   'SM-N920R4': 832,
#   'SM-P550 Build/NMF26X': 833,
#   'SM-S550TL': 834,
#   'A621R': 835,
#   'SAMSUNG SM-N950F Build/NMF26X': 836,
#   'LG-H810/H81022f': 837,
#   'F5121 Build/34.3.A.0.252': 838,
#   'SGH-M919N': 839,
#   'H1611': 840,
#   'XT1063 Build/MPB24.65-34-3': 841,
#   'LGL52VL Build/LMY47V': 842,
#   'SM-N920A Build/MMB29K': 843,
#   'G3223 Build/42.0.A.4.101': 844,
#   'LG-LK460': 845,
#   'XT1094': 846,
#   'P5026A': 847,
#   'SAMSUNG-SM-G530AZ Build/LMY48B': 848,
#   'LGLS665 Build/LMY47V': 849,
#   'SAMSUNG SM-N900T Build/LRX21V': 850,
#   'SM-G610M Build/NRD90M': 851,
#   'Z833': 852,
#   'LG-D850': 853,
#   'D6503': 854,
#   'SM-A720F Build/NRD90M': 855,
#   'SAMSUNG SM-J530GM Build/NRD90M': 856,
#   'Moto C Build/NRD90M.046': 857,
#   'ZTE A2017U Build/NRD90M': 858,
#   'GT-N7100': 859,
#   'SAMSUNG SM-J710MN Build/MMB29K': 860,
#   'XT1063 Build/MPB24.65-34': 861,
#   'SM-P605V': 862,
#   'rv:37.0': 863,
#   'SAMSUNG SM-G928G Build/NRD90M': 864,
#   'Lenovo TAB 2 A7-30GC Build/KOT49H': 865,
#   'LG-K428 Build/NRD90U': 866,
#   'BLU STUDIO C 5+5 Build/LRX21M': 867,
#   'F3113': 868,
#   'SM-S975L': 869,
#   'XT1097': 870,
#   'MotoG3-TE Build/MPDS24.65-33-1-3': 871,
#   '0PM92': 872,
#   'D2306': 873,
#   'MYA-L13 Build/HUAWEIMYA-L13': 874,
#   'LG-H700 Build/NRD90U': 875,
#   'A50C+': 876,
#   'SAMSUNG SM-G900M Build/LRX21T': 877,
#   '5095I Build/MRA58K': 878,
#   'LG-V495': 879,
#   'F3213 Build/36.0.A.2.146': 880,
#   'A1601 Build/LMY47I': 881,
#   'LGUS991': 882,
#   'SAMSUNG-SM-T807A': 883,
#   'S6000': 884,
#   'SM-J320VPP': 885,
#   'rv:52.9': 886,
#   'SAMSUNG SM-T800 Build/MMB29K': 887,
#   'Intel': 888,
#   'Blade A475 Build/LMY47D': 889,
#   'LG-K550': 890,
#   'E5506': 891,
#   'SAMSUNG SM-G900I Build/MMB29M': 892,
#   'Win64': 893,
#   '0PJA2': 894,
#   'BLU ENERGY X PLUS Build/LRX21M': 895,
#   'SM-A710M Build/NRD90M': 896,
#   '5015A Build/LMY47I': 897,
#   'SAMSUNG SM-J530F Build/NRD90M': 898,
#   'SM-G900L': 899,
#   'ASUS_P00J': 900,
#   'TA-1025': 901,
#   'SM-S327VL': 902,
#   'A0001 Build/MHC19Q': 903,
#   'GT-I9195L': 904,
#   '6039A Build/LRX22G': 905,
#   'SM-A800I': 906,
#   'LG-D959': 907,
#   'SM-G900V Build/LRX21T': 908,
#   'SAMSUNG SM-G930R4 Build/NRD90M': 909,
#   'LGL83BL': 910,
#   'SM-G928P': 911,
#   'C6906 Build/14.6.A.1.236': 912,
#   'K92': 913,
#   'K90U': 914,
#   'SAMSUNG-SM-G935A': 915,
#   'XT1580 Build/NPKS25.200-12-9': 916,
#   'SM-A310F Build/NRD90M': 917,
#   'BOIE9': 918,
#   'SM-T377P': 919,
#   'LG-LS995': 920,
#   'LGUS990': 921,
#   'SM-G935U': 922,
#   'XT1021 Build/KXC21.5-40': 923,
#   'KIW-L24': 924,
#   'SM-T377T': 925,
#   'rv:43.0': 926,
#   'LG-D320 Build/KOT49I.V10a': 927,
#   'Alcatel_5044R Build/NRD90M': 928,
#   'SAMSUNG-SM-N910A': 929,
#   'HTC6500LVW': 930,
#   'XT1575 Build/NPHS25.200-23-1': 931,
#   'RS988': 932,
#   'LG-H931': 933,
#   'RCT6S03W12': 934,
#   'SAMSUNG-SM-G920A Build/MMB29K': 935,
#   'SM-T807T': 936,
#   'CAM-L23': 937,
#   'SM-T817T': 938,
#   'SM-J727P': 939,
#   'SM-G550T2': 940,
#   'VS985': 941,
#   'LG-H815 Build/MRA58K': 942,
#   'SM-G900P': 943,
#   'SAMSUNG SM-J320M Build/LMY47V': 944,
#   'BBA100-1': 945,
#   '831C': 946,
#   'LG-H830': 947,
#   'ALCATEL ONE TOUCH 7047A Build/JDQ39': 948,
#   'SM-G800F Build/MMB29K': 949,
#   'SM-E700M': 950,
#   'SAMSUNG SM-J710MN Build/NRD90M': 951,
#   'Z831': 952,
#   'GT-P3100': 953,
#   'E5606': 954,
#   'SAMSUNG-SM-G900A': 955,
#   'ASUS_Z00UD': 956,
#   'SM-N900P Build/LRX21V': 957,
#   'LG-V700': 958,
#   'SAMSUNG SM-J700T1 Build/NMF26X': 959,
#   'P008 Build/NRD90M': 960,
#   'ONEPLUS': 961,
#   'SAMSUNG-SM-J320A Build/NMF26X': 962,
#   'SM-G800M Build/KOT49H': 963,
#   'BBB100-2': 964,
#   'LG-D680': 965,
#   'SM-S727VL Build/MMB29M': 966,
#   'F3313': 967,
#   'ONE': 968,
#   'D5106': 969,
#   'SAMSUNG-SGH-I337': 970,
#   'LGL84VL Build/NRD90U': 971,
#   'TA-1028 Build/NMF26O': 972,
#   'YOGA': 973,
#   'D5316': 974,
#   'SPH-L720': 975,
#   'SM-N915V': 976,
#   '0PAJ5': 977,
#   'RCT6513W87 Build/MRA58K': 978,
#   'E6853 Build/32.4.A.1.54': 979,
#   'SM-G720AX': 980,
#   'SM-G900M Build/MMB29M': 981,
#   '6045I Build/LRX22G': 982,
#   'Android 6.0': 983,
#   'E2006': 984,
#   'BBB100-1': 985,
#   'GT-I9060L Build/JDQ39': 986,
#   'SM-T530': 987,
#   'Infinit': 988,
#   'SM-J110M Build/LMY48B': 989,
#   'LG-D213': 990,
#   'LAVA_A3': 991,
#   'GT-S7390': 992,
#   'Alcatel_5054O': 993,
#   'Lenovo YT3-X50F Build/MMB29M': 994,
#   'SAMSUNG-SM-G925A': 995,
#   'SM-A300H': 996,
#   'HUAWEI Build/MMB28B': 997,
#   'Ilium L620 Build/NRD90M': 998,
#   'SM-N910P': 999,
#   ...}}

# %%
get_string_features(train)
# Out:
# []

# %% [markdown]
# # Reduce Memory Usage for KFold

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
# %time train = reduce_mem_usage(train)
# Out:
# Memory usage after optimization is: 529.96 MB
# Decreased by 73.0%
# CPU times: user 1min 3s, sys: 2min 8s, total: 3min 11s
# Wall time: 1min 35s

# %% [markdown]
# # Undersample majority class

# %%
def preprocess(df):
    df = df.fillna(-999)
    
    return df.drop(columns=['TransactionID', 'TransactionDT'])


train = preprocess(train)

# %%
train.shape
# Out:
# (590540, 432)

# %%
def split_features_labels(df):
    return df.drop(columns=['isFraud']), df['isFraud']

# %%
# def undersample_then_oversample(df, random_state=27):
#     """
#     Upsample minority class (isFraud=1), combine with majority class, and then shuffle them.
#     """
#     sampling_strategy = 0.5
# #     X = df.drop(columns=['isFraud'])
# #     y = df['isFraud']
#     X, y = split_features_labels(df)
    
#     # Declare Random Under Sampler
#     rus = NearMiss(version=3, 
#                    sampling_strategy=sampling_strategy,
#                    n_jobs=cpu_count(),
#                    random_state=random_state)
    
#     ros = SMOTE(n_jobs=cpu_count(),
#                random_state=random_state)
    
#     X, y = rus.fit_resample(X, y)
#     X, y = ros.fit_resample(X, y)
    
#     return X, y.astype('int32')


# %time X, y = undersample_then_oversample(train)

# %%
def oversample(df, random_state=27):
    """
    Upsample minority class (isFraud=1), combine with majority class, and then shuffle them.
    """
    sampling_strategy = 0.15
#     X = df.drop(columns=['isFraud'])
#     y = df['isFraud']
    X, y = split_features_labels(df)
    
    ros = SMOTE(sampling_strategy=sampling_strategy,
                n_jobs=cpu_count(),
               random_state=random_state)
    
    X, y = ros.fit_resample(X, y)
    
    return X, y.astype('int32')


# %time X, y = oversample(train)
# Out:
# CPU times: user 43.8 s, sys: 2.82 s, total: 46.6 s
# Wall time: 16.1 s

# %%
print(X.shape)
print(y.shape)
# Out:
# (655358, 431)
# (655358,)

# %%
Counter(y)
# Out:
# Counter({0: 569877, 1: 85481})

# %% [markdown]
# # Train using XGB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590540 entries, 0 to 590539
# Columns: 432 entries, isFraud to DeviceInfo
# dtypes: float16(354), float32(45), int16(4), int8(29)
# memory usage: 525.4 MB

# %%
del train

import gc
gc.collect()
# Out:
# 54

# %%
seed = 27

random_state = seed
epochs = 5

kf = StratifiedKFold(n_splits=epochs,
                    random_state=random_state,
                    shuffle=True)

model = xgb.XGBClassifier(objective='binary:logistic',
                            n_jobs=cpu_count(),
                            seed=seed,
#                             n_estimators=500,
#                             max_depth=17,
#                             learning_rate=0.03,
                            subsample=0.9,
                            colsample_bytree=0.9,)

scores = []

for index, (index_train, index_valid) in tqdm(enumerate(kf.split(X, y))):
    X_train, y_train = X[index_train, :], y[index_train]
    
    model.fit(X_train, y_train)
    
    del X_train
    del y_train
    gc.collect()
    
    X_valid, y_valid = X[index_valid, :], y[index_valid]
    y_pred_prob_valid = model.predict_proba(X_valid)
    score = roc_auc_score(y_valid, y_pred_prob_valid[:, 1])
    
    del X_valid
    del y_valid
    gc.collect()
    

    scores.append(score)
    print('Fold {}, roc-auc score={}'.format(index,
                                             score))
  

print('Average score={}'.format(np.mean(scores)))
# Out:
# 1it [02:59, 179.05s/it]
# Fold 0, roc-auc score=0.9597420454055278
# 2it [05:58, 179.31s/it]
# Fold 1, roc-auc score=0.9603108516117753
# 3it [08:58, 179.50s/it]
# Fold 2, roc-auc score=0.963254022059653
# 4it [11:57, 179.24s/it]
# Fold 3, roc-auc score=0.961910065841882
# 5it [14:55, 178.88s/it]
# Fold 4, roc-auc score=0.961236467526117
# Average score=0.961290690488991

# %%
pred_prob = model.predict_proba(X)

score = roc_auc_score(y, pred_prob[:, 1])

print('roc-auc score={}'.format(score))
# Out:
# roc-auc score=0.9616845932433111

# %%
print(model)

# %% [markdown]
# # Save Model

# %%
import pickle

filename_model = './models/xgboost/kfold_encoded_transaction_identity_oversampling_2019_0805.pkl'

with open(filename_model, 'wb') as f:
    pickle.dump(model, f)

# %%
del X
del y

import gc
gc.collect()
# Out:
# 80

# %% [markdown]
# # Predict Test Data And Write to File

# %%
filename = './datasets/test_transaction.csv'
filename_identity = './datasets/test_identity.csv'
# filename_identity = None
# %time test = read_data(filename, filename_identity, drop_string_features=False)
# Out:
# CPU times: user 21.8 s, sys: 5.76 s, total: 27.5 s
# Wall time: 26.8 s

# %%
test.head()
# Out:
#    TransactionID  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# 0        3663549       18403224           31.95         W  10409  111.0
# 1        3663550       18403263           49.00         W   4272  111.0
# 2        3663551       18403310          171.00         W   4476  574.0
# 3        3663552       18403310          284.95         W  10989  360.0
# 4        3663553       18403317           67.95         W  18018  452.0
#
#    card3       card4  card5  card6  ...  id_31  id_32  id_33  id_34 id_35  \
# 0  150.0        visa  226.0  debit  ...    NaN    NaN    NaN    NaN   NaN
# 1  150.0        visa  226.0  debit  ...    NaN    NaN    NaN    NaN   NaN
# 2  150.0        visa  226.0  debit  ...    NaN    NaN    NaN    NaN   NaN
# 3  150.0        visa  166.0  debit  ...    NaN    NaN    NaN    NaN   NaN
# 4  150.0  mastercard  117.0  debit  ...    NaN    NaN    NaN    NaN   NaN
#
#   id_36  id_37  id_38  DeviceType  DeviceInfo
# 0   NaN    NaN    NaN         NaN         NaN
# 1   NaN    NaN    NaN         NaN         NaN
# 2   NaN    NaN    NaN         NaN         NaN
# 3   NaN    NaN    NaN         NaN         NaN
# 4   NaN    NaN    NaN         NaN         NaN
#
# [5 rows x 433 columns]

# %%
_ = encode(test, mappings)

# %%
test_id = test['TransactionID']

# %%
test.shape
# Out:
# (506691, 433)

# %%
# %time test = preprocess(test)
# Out:
# CPU times: user 2.16 s, sys: 3.32 s, total: 5.48 s
# Wall time: 3.28 s

# %%
test.head()
# Out:
#    TransactionAmt  ProductCD  card1  card2  card3  card4  card5  card6  addr1  \
# 0           31.95          0  10409  111.0  150.0      2  226.0      1  170.0
# 1           49.00          0   4272  111.0  150.0      2  226.0      1  299.0
# 2          171.00          0   4476  574.0  150.0      2  226.0      1  472.0
# 3          284.95          0  10989  360.0  150.0      2  166.0      1  205.0
# 4           67.95          0  18018  452.0  150.0      1  117.0      1  264.0
#
#    addr2  ...  id_31  id_32  id_33  id_34  id_35  id_36  id_37  id_38  \
# 0   87.0  ...    0.0 -999.0    0.0      0      0      0      0      0
# 1   87.0  ...    0.0 -999.0    0.0      0      0      0      0      0
# 2   87.0  ...    0.0 -999.0    0.0      0      0      0      0      0
# 3   87.0  ...    0.0 -999.0    0.0      0      0      0      0      0
# 4   87.0  ...    0.0 -999.0    0.0      0      0      0      0      0
#
#    DeviceType  DeviceInfo
# 0           0         0.0
# 1           0         0.0
# 2           0         0.0
# 3           0         0.0
# 4           0         0.0
#
# [5 rows x 431 columns]

# %%
# del X
# import gc
# gc.collect()

# %%
# %time pred_prob = model.predict_proba(test.values)
# Out:
# CPU times: user 6.29 s, sys: 2.63 s, total: 8.92 s
# Wall time: 4.68 s

# %%
test_result_df = pd.DataFrame(test_id, columns=['TransactionID'])
test_result_df['isFraud'] = pred_prob[:, 1]

filename_prediction = './prediction_test_kfold_oversampling_encoded_transaction_identity_2019_0805.csv'
# %time test_result_df.to_csv(filename_prediction, index=False)
# Out:
# CPU times: user 2.15 s, sys: 309 µs, total: 2.15 s
# Wall time: 2.08 s
